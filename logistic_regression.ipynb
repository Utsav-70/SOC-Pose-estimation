# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, log_loss
import joblib

# %%
train_data = pd.read_csv('Downloads/train (1).csv')
null_values = train_data.isnull()

# Count the number of null values in each column
null_count = null_values.sum()

# Print the null count for each column
print(null_count)
test_data= pd.read_csv('Downloads/test (1).csv')
null_values1 = test_data.isnull()

# Count the number of null values in each column
null_count1 = null_values1.sum()

# Print the null count for each column
print(null_count1)
# Out:
# x        0
# y        0
# color    0
# dtype: int64
# x        0
# y        0
# color    0
# dtype: int64

# %%
X_train = train_data[['x', 'y']]
Y_train = train_data['color']

# Split the testing data into input features (X_test)
X_test = test_data[['x', 'y']]
Y_test = test_data[['color']]

# %%
accuracy = accuracy_score(Y_test, predicted_colors)
print(f"Accuracy: {accuracy}")

# Calculate and print the cross-entropy loss
probabilities = model.predict_proba(X_test)
logloss = log_loss(Y_test, probabilities)
print(f"Log Loss: {logloss}")
# Out:
# Accuracy: 0.9933333333333333
# Log Loss: 0.0992746716720699

# %%
for coordinates, color in zip(X_test.values, predicted_colors):
    print(f"Coordinates {coordinates} are predicted to be {color}")
# Out:
# Coordinates [-0.17386771  1.38185241] are predicted to be red
# Coordinates [-0.7241481   1.88300767] are predicted to be red
# Coordinates [-0.42391535  1.40829694] are predicted to be red
# Coordinates [-0.65016195  1.29606711] are predicted to be red
# Coordinates [0.95793304 0.63311069] are predicted to be red
# Coordinates [-0.77098127  0.20790296] are predicted to be red
# Coordinates [-0.12506848  0.27139767] are predicted to be red
# Coordinates [-0.68613055  1.59192979] are predicted to be red
# Coordinates [-0.30326652  1.75947755] are predicted to be red
# Coordinates [-0.03046445  0.41149446] are predicted to be red
# Coordinates [0.93137603 0.22433169] are predicted to be red
# Coordinates [-0.70509362  1.48256699] are predicted to be red
# Coordinates [0.14578618 1.76422651] are predicted to be red
# Coordinates [-0.32352394  0.40176833] are predicted to be red
# Coordinates [0.5107334  1.74345795] are predicted to be red
# ...

# %%
joblib.dump(model, 'logistic_regression_model.pkl')
# Out:
# ['logistic_regression_model.pkl']

# %%
# Out:
# ['.conda',
#  '.condarc',
#  '.continuum',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.snap',
#  '.vscode',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'c++.cpp',
#  'CLionProjects',
#  'color and marker prediction.pkl',
#  'colour_and_markers.ipynb',
#  'combined model.ipynb',
#  'combined_model.joblib',
#  'combined_model_final.pkl',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'install.log',
#  'IntelGraphicsProfiles',
#  'java_error_in_clion64_32972.log',
#  'Links',
#  'Local Settings',
#  'logistic_regression_model.pkl',
#  'mode house rent4.ipynb',
#  'model color and marker prediction.pkl',
#  'model colours and markers.pkl',
#  'model house rent.pkl',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{ca2a5e38-d565-11eb-835b-0045e27ab950}.TM.blf',
# ...
